# %% [markdown]
# @Author: Rikesh Chhetri
#
# @Date: 2021-07-14
#
# @Last Modified by: Rikesh Chhetri
#
# @Last Modified time: 2021-07-14 07:03:30
#
# @Title :  Program to create multiple plots.

# %%
from matplotlib import pyplot as plt
import numpy as np 
from LogHandler import logger

try:
    x1 = [1, 2, 3]
    y1 = [4, 5, 6]
    
    plt.subplot(1, 2, 1)
    plt.plot(x1, y1)
    
    plt.subplot(1, 2, 2)
    plt.plot([2, 1], [2, 3])

except Exception as e:
    logger.error(e)

# %% [markdown]
# @Author: Rikesh Chhetri
#
# @Date: 2021-07-14
#
# @Last Modified by: Rikesh Chhetri
#
# @Last Modified time: 2021-07-14 07:03:30
#
# @Title :  Program to create multiple types of chart.

# %%
from matplotlib import pyplot as plt
from LogHandler import logger

try:
    names = ['group_a','group_b','group_c']
    values = [10,50,100]
    plt.figure(figsize=(14,6))
    plt.subplot(131)
    plt.bar(names,values)

    plt.subplot(132)
    plt.plot(names,values)

    plt.subplot(133)
    plt.scatter(names,values)

    

except Exception as e:
    logger.error(e)
